# %%
import pandas as pd
import gspread

import youtube_dl
ytdlopts = {
    'format': 'bestaudio/best',
    'outtmpl': 'downloads/%(extractor)s-%(id)s-%(title)s.%(ext)s',
    'restrictfilenames': True,
    'noplaylist': True,
    'nocheckcertificate': True,
    'ignoreerrors': False,
    'logtostderr': False,
    'quiet': True,
    'no_warnings': True,
    'default_search': 'auto',
    'source_address': '0.0.0.0'  # ipv6 addresses cause issues sometimes
}
ytdl = youtube_dl.YoutubeDL(ytdlopts)

# %%
def get_ytb_track_data(self, row):
    data = ytdl.extract_info(url=row.URL, download=False)
    if 'entries' in data:
        if len(data['entries']) == 1:  # for search single song
            data['duration'] = data['entries'][0]['duration']
            data['view_count'] = data['entries'][0]['view_count']
            data['categories'] = data['entries'][0]['categories']

    duration = get_readable_duration(data['duration']) if 'duration' in data else ""
    views = f"{data['view_count']:,}" if 'view_count' in data else ""
    categories = ', '.join(data['categories']) if 'categories' in data else ""

    return duration, views, categories

def get_readable_duration(duration):
    """Get duration in hours, minutes and seconds."""

    m, s = divmod(int(duration), 60)
    h, m = divmod(m, 60)

    if h:
        duration = f"{h}:{m:02d}:{s:02d}"
    else:
        duration = f"{m}:{s:02d}"

    return duration

# %%
# get pandas format
gc = gspread.service_account(filename='credentials.json')
sh = gc.open("Discord Music Log")
cmd_wks = sh.worksheet("Commands Log2")
cmd_df = pd.DataFrame(cmd_wks.get_all_records())
cmd_df['Date'] = pd.to_datetime(cmd_df['Date'])
now = pd.Timestamp.now()
sheet_name = "Track Log (year)"
offset = pd.DateOffset(years=1)

track_wks = sh.worksheet(sheet_name)
track_df = pd.DataFrame(track_wks.get_all_records())
if track_df.empty:
    track_df = pd.DataFrame(columns=[
        'First time requested', 'Last time requested',
        'Requests', 'Title', 'URL',
        'Duration', 'Views', 'Categories'
    ])
track_df.head(60)
# Out:
# Empty DataFrame
# Columns: [First time requested, Last time requested, Requests, Title, URL, Duration, Views, Categories]
# Index: []

# %%
# filter months
if offset:
    timestamp = now - offset
    filter_ = cmd_df['Date'] >= timestamp
    filtered_cmd_df = cmd_df[filter_]
else:
    filtered_cmd_df = cmd_df
filtered_cmd_df
# Out:
#                     Date      Author  \
# 3175 2021-05-27 12:16:17      Bogori
# 3176 2021-05-27 12:21:40  Freezpmark
# 3177 2021-05-27 12:35:48      Bogori
# 3178 2021-05-27 12:39:28      Bogori
# 3179 2021-05-27 12:44:22  Freezpmark
# ...                  ...         ...
# 3537 2022-04-27 22:29:40  Freezpmark
# 3538 2022-04-27 22:29:50  Freezpmark
# 3539 2022-04-27 23:29:56  Freezpmark
# 3540 2022-04-27 23:29:57  Freezpmark
# 3541 2022-04-27 22:29:56  Freezpmark
#
#                                                   Title  \
# 3175             21st Century Schizoid Man (Radio Edit)
# 3176                        Kingslayer「AMV」 Fate Series
# 3177               NIVIRO - The Labyrinth [NCS Release]
# 3178  Here Comes the Hotstepper (Evian version - Yuk...
# 3179  Doki Doki Literature Club! OST - Doki Doki Lit...
# ...                                                 ...
# 3537          Perturbator - Ghost Dancers Slay Together
# 3538                                     Vogel im Käfig
# 3539                                     Vogel im Käfig
# 3540  Crystal Waters - Gypsy Woman (She's Homeless) ...
# 3541                                     Vogel im Käfig
#
#                                               URL
# 3175  https://www.youtube.com/watch?v=AWCV9LLTHx0
# 3176  https://www.youtube.com/watch?v=oxDKF_x3Efc
# 3177  https://www.youtube.com/watch?v=4S0shEqJ8Vc
# 3178  https://www.youtube.com/watch?v=nlqNHp3qsdU
# 3179  https://www.youtube.com/watch?v=BFSWlDpA6C4
# ...                                           ...
# 3537  https://www.youtube.com/watch?v=m8Ap8nVB2p8
# 3538  https://www.youtube.com/watch?v=H76_uW1Fnso
# 3539  https://www.youtube.com/watch?v=H76_uW1Fnso
# 3540  https://www.youtube.com/watch?v=_KztNIg4cvE
# 3541  https://www.youtube.com/watch?v=H76_uW1Fnso
#
# [367 rows x 4 columns]

# %%
# groupby titles
grouped_cmd_df = filtered_cmd_df.groupby(["Title", "URL"])["Date"]
function_list = [("First time requested", "min"), ("Last time requested", "max"), ("Requests", "count")]
grouped_cmd_df = grouped_cmd_df.agg(function_list).reset_index()
grouped_cmd_df
# Out:
#                                                  Title  \
# 0                                                 2022
# 1                 (ENG) Dreamcatcher(드림캐쳐) 'MAISON' MV
# 2    06 - Gakuen Tengoku (Full Hensei Ver.) ~ Hibik...
# 3      10 - RYDEEN ~ Hibike! Euphonium - [Zona Random]
# 4               21st Century Schizoid Man (Radio Edit)
# ..                                                 ...
# 241  「Creditless」Kaguya-sama: Love is War OP / Open...
# 242                 【東方ヴォーカルPV】Necromantic【暁Records公式】
# 243               ろん -「おちゃめ機能」FUKKIRETA 【HD.256k.Kara】
# 244                                                 喜劇
# 245                                      美波「カワキヲアメク」MV
#
#                                                    URL First time requested  \
# 0    https://www.youtube.com/playlist?list=PLgLNILF...  2022-04-27 22:29:14
# 1          https://www.youtube.com/watch?v=z4t9LLq1Nk0  2022-04-17 12:46:46
# 2          https://www.youtube.com/watch?v=0xj11x6eDuI  2022-04-27 14:37:06
# 3          https://www.youtube.com/watch?v=_ic07gdsGYQ  2022-04-27 14:33:59
# 4          https://www.youtube.com/watch?v=AWCV9LLTHx0  2021-05-27 12:16:17
# ..                                                 ...                  ...
# 241        https://www.youtube.com/watch?v=kkVNjjUgYdY  2021-08-20 15:47:05
# 242        https://www.youtube.com/watch?v=RtTYQuO1j6w  2022-04-17 13:54:30
# 243        https://www.youtube.com/watch?v=kuNixp-wvWM  2022-04-17 13:45:08
# 244        https://www.youtube.com/watch?v=URR_Nv-6MZs  2022-04-10 15:13:17
# 245        https://www.youtube.com/watch?v=0YF8vecQWYs  2021-09-14 15:29:33
#
#     Last time requested  Requests
# 0   2022-04-27 22:29:18         2
# 1   2022-04-18 18:09:03         2
# 2   2022-04-27 14:37:06         1
# 3   2022-04-27 14:33:59         1
# 4   2021-05-27 12:16:17         1
# ..                  ...       ...
# 241 2022-04-18 21:15:35         2
# 242 2022-04-17 13:54:30         1
# 243 2022-04-17 13:45:08         1
# 244 2022-04-10 15:13:17         1
# 245 2021-09-14 15:29:33         1
#
# [246 rows x 5 columns]

# %%
# groupby titles
grouped_cmd_df = filtered_cmd_df.groupby(["URL", "Title"])["Date"]
function_list = [("First time requested", "min"), ("Last time requested", "max"), ("Requests", "count")]
grouped_cmd_df = grouped_cmd_df.agg(function_list).reset_index()

# merge with track_df, rearrange, clean data
# cols_to_use = track_df.columns.difference(grouped_cmd_df.columns)
# track_df = track_df.sort_values(["Title", "URL"])
track_df = track_df.drop(labels=["First time requested", "Last time requested", "Requests", "Title"], axis=1)
merged_df = pd.merge(grouped_cmd_df, track_df, on='URL', how="left")
merged_df
grouped_cmd_df
# merged_df = merged_df[[
#                 'First time requested', 'Last time requested',
#                 'Requests', 'Title', 'URL',
#                 'Duration', 'Views', 'Categories'
#             ]]
# Out:
#                                                    URL  \
# 0    https://www.youtube.com/playlist?list=PLHqc-xB...
# 1    https://www.youtube.com/playlist?list=PLgLNILF...
# 2    https://www.youtube.com/playlist?list=PLqynaP0...
# 3          https://www.youtube.com/watch?v=--9kqhzQ-8Q
# 4          https://www.youtube.com/watch?v=-81PSoMeTUM
# ..                                                 ...
# 241        https://www.youtube.com/watch?v=zVch_PK7SOY
# 242        https://www.youtube.com/watch?v=zWaymcVmJ-A
# 243        https://www.youtube.com/watch?v=zZMg9ryeWOw
# 244        https://www.youtube.com/watch?v=zroFzv7sFis
# 245  https://youtube.com/playlist?list=PLgLNILF9oiE...
#
#                                                  Title First time requested  \
# 0          Dano Drevo a turnaj mekyho žbirku Full List  2022-04-01 13:44:33
# 1                                                 2022  2022-04-27 22:29:14
# 2                 Painkiller Black Edition OST (fight)  2022-04-01 16:45:26
# 3                         H.Y.C.Y.BH? (Official Video)  2022-04-02 15:44:23
# 4    KAGUYA-SAMA WA KOKURASETAI TENSAITACHI NO REN'...  2022-04-10 15:01:03
# ..                                                 ...                  ...
# 241                               Pendulum - Tarantula  2022-04-18 20:12:26
# 242        Los Del Rio - Macarena (Bayside Boys Remix)  2022-04-17 13:19:35
# 243                       Mick Gordon - 02. Rip & Tear  2021-08-17 19:42:02
# 244                                     ətˈæk 0N tάɪtn  2022-04-18 19:40:18
# 245                          [MUSIC] 2020 (Deep House)  2021-06-17 17:32:38
#
#     Last time requested  Requests
# 0   2022-04-01 14:45:42         2
# 1   2022-04-27 22:29:18         2
# 2   2022-04-01 16:45:26         1
# 3   2022-04-03 17:52:06         2
# 4   2022-04-10 15:01:03         1
# ..                  ...       ...
# 241 2022-04-18 20:12:26         1
# 242 2022-04-17 13:19:35         1
# 243 2022-04-03 19:06:09         2
# 244 2022-04-18 19:40:18         1
# 245 2021-06-17 17:32:38         1
#
# [246 rows x 5 columns]

# %%
# track_df.reset_index(drop=True)
merged_df
# Out:
#                                                    URL  \
# 0    https://www.youtube.com/playlist?list=PLHqc-xB...
# 1    https://www.youtube.com/playlist?list=PLgLNILF...
# 2    https://www.youtube.com/playlist?list=PLqynaP0...
# 3          https://www.youtube.com/watch?v=--9kqhzQ-8Q
# 4          https://www.youtube.com/watch?v=-81PSoMeTUM
# ..                                                 ...
# 241        https://www.youtube.com/watch?v=zVch_PK7SOY
# 242        https://www.youtube.com/watch?v=zWaymcVmJ-A
# 243        https://www.youtube.com/watch?v=zZMg9ryeWOw
# 244        https://www.youtube.com/watch?v=zroFzv7sFis
# 245  https://youtube.com/playlist?list=PLgLNILF9oiE...
#
#                                                  Title First time requested  \
# 0          Dano Drevo a turnaj mekyho žbirku Full List  2022-04-01 13:44:33
# 1                                                 2022  2022-04-27 22:29:14
# 2                 Painkiller Black Edition OST (fight)  2022-04-01 16:45:26
# 3                         H.Y.C.Y.BH? (Official Video)  2022-04-02 15:44:23
# 4    KAGUYA-SAMA WA KOKURASETAI TENSAITACHI NO REN'...  2022-04-10 15:01:03
# ..                                                 ...                  ...
# 241                               Pendulum - Tarantula  2022-04-18 20:12:26
# 242        Los Del Rio - Macarena (Bayside Boys Remix)  2022-04-17 13:19:35
# 243                       Mick Gordon - 02. Rip & Tear  2021-08-17 19:42:02
# 244                                     ətˈæk 0N tάɪtn  2022-04-18 19:40:18
# 245                          [MUSIC] 2020 (Deep House)  2021-06-17 17:32:38
#
#     Last time requested  Requests Duration Views Categories
# 0   2022-04-01 14:45:42         2      NaN   NaN        NaN
# 1   2022-04-27 22:29:18         2      NaN   NaN        NaN
# 2   2022-04-01 16:45:26         1      NaN   NaN        NaN
# 3   2022-04-03 17:52:06         2      NaN   NaN        NaN
# 4   2022-04-10 15:01:03         1      NaN   NaN        NaN
# ..                  ...       ...      ...   ...        ...
# 241 2022-04-18 20:12:26         1      NaN   NaN        NaN
# 242 2022-04-17 13:19:35         1      NaN   NaN        NaN
# 243 2022-04-03 19:06:09         2      NaN   NaN        NaN
# 244 2022-04-18 19:40:18         1      NaN   NaN        NaN
# 245 2021-06-17 17:32:38         1      NaN   NaN        NaN
#
# [246 rows x 8 columns]

# %%
track_df
# Out:
# Empty DataFrame
# Columns: [Title, Duration, Views, Categories]
# Index: []

# %%
for i, row in enumerate(merged_df.head(24).itertuples()):
    ytb_stats = row.Duration, row.Views, row.Categories
    if not all(ytb_stats):
        try:
            duration, views, categories = self.get_ytb_track_data(row)
        except Exception as e:
            print(f"{i}. error: {e}. (row: {row})")
            continue

        merged_df.at[row.Index, 'Duration'] = duration.replace(":", "︰")
        merged_df.at[row.Index, 'Views'] = views
        merged_df.at[row.Index, 'Categories'] = categories
        print(f"Updated {i} row.")

# save to gsheets
listed_table_result = [merged_df.columns.values.tolist()] + merged_df.values.tolist()  # first part is for header
track_wks.update(listed_table_result, value_input_option='USER_ENTERED')  # value_input_option='USER_ENTERED' / 'RAW'
# Out:
#      First time requested  Last time requested  Requests  \
# 826   2020-09-17 21:10:04  2020-09-17 21:10:04         1
# 967   2019-04-25 20:38:53  2019-04-25 20:38:53         1
# 966   2020-03-03 21:37:43  2020-03-03 21:37:43         1
# 965   2019-04-15 20:54:43  2019-04-15 20:54:43         1
# 964   2019-10-11 22:20:55  2019-10-11 22:20:55         1
# ...                   ...                  ...       ...
# 445   2020-09-19 22:09:42  2022-04-03 18:58:14        25
# 393   2019-03-31 19:54:25  2022-04-10 16:03:27        26
# 34    2019-03-16 18:48:29  2021-08-20 15:23:27        26
# 1565  2019-03-22 21:26:52  2022-04-10 16:13:09        29
# 946   2019-04-24 23:24:59  2020-11-03 23:27:56        29
#
#                                                   Title  \
# 826                                Kopytovci - Dojit HD
# 967   MinAh - Cry Me Out / I am a Woman Too [Yu Huiy...
# 966        Milky Chance - Stolen Dance (Official Video)
# 965      Miley Cyrus - The Backyard Sessions - 'Jolene'
# 964      Miho Hazama: Dancer in Nowhere feat. Nate Wood
# ...                                                 ...
# 445                      Dreamcatcher(드림캐쳐) 'Scream' MV
# 393   Devil May Cry 5 - Devil Trigger (Ali Edwards) ...
# 34                           4MINUTE(포미닛) - 싫어(Hate) MV
# 1565  [Full Song/Official Lyrics] Devil Trigger - Ne...
# 946                                    Melisko - Mravce
#
#                                               URL Duration       Views  \
# 826   https://www.youtube.com/watch?v=0khMME8R2Fc     2︰16     4336679
# 967   https://www.youtube.com/watch?v=RxfoFcNYDc4     4︰31     2191096
# 966   https://www.youtube.com/watch?v=iX-QaNzd-0Y     4︰40     2193950
# 965   https://www.youtube.com/watch?v=wOwblaKmyVw     3︰19     2202357
# 964   https://www.youtube.com/watch?v=q-z-2SXmlnE    10︰31     2204418
# ...                                           ...      ...         ...
# 445   https://www.youtube.com/watch?v=FKlGHHhTOsQ     3︰58    36425860
# 393   https://www.youtube.com/watch?v=XpPaTM48h74     3︰43    50946803
# 34    https://www.youtube.com/watch?v=D_F9HUTYnl0     3︰47  1210343404
# 1565  https://www.youtube.com/watch?v=-WpnPSChVRQ     3︰55       23780
# 946   https://www.youtube.com/watch?v=p96Ig2ip2kE     2︰57     2405686
#
#      Categories
# 826       Music
# 967       Music
# 966       Music
# 965       Music
# 964       Music
# ...         ...
# 445       Music
# 393       Music
# 34        Music
# 1565      Music
# 946       Music
#
# [1654 rows x 8 columns]

# %%
# pd.set_option('display.max_rows', 100)

# grouped_cmd_df[['Duration', 'Views', 'Categories']] = 0
# grouped_cmd_df = grouped_cmd_df[[
#     'First time requested', 'Last time requested',
#     'Requests', 'Title', 'URL',
#     'Duration', 'Views', 'Categories'
# ]]
# grouped_cmd_df

# track_df = track_df.sort_values(["Title", "URL"]).reset_index(drop=True)
# track_df
# rows = (grouped_cmd_df[['Title']] == track_df[['Title']]).all(axis=1)
# grouped_cmd_df.loc[rows, 'Views'] = track_df.loc[rows, 'Views']
# grouped_cmd_df

# # mask = grouped_cmd_df[['Title']].isin(track_df[['Title']]).all(1)
# # grouped_cmd_df.Views = grouped_cmd_df.Views.mask(mask).combine_first(track_df.Views)
# # grouped_cmd_df.head(60)

# rows = (grouped_cmd_df[['Title','URL']] == track_df[['Title','URL']]).all(axis=1)
# grouped_cmd_df.loc[rows,'Views'] = track_df.loc[rows,'Views']
# #grouped_cmd_df[['Duration', 'Views', 'Categories']] = track_df[['Duration', 'Views', 'Categories']]
# grouped_cmd_df
